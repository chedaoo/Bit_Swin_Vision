# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import random

import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch
import torch.optim as optim
torch.cuda.set_device(0)
from torch.utils.data import Dataset
from PIL import Image
import torch.nn as nn

import warnings
warnings.filterwarnings("ignore")

import glob

from sklearn.model_selection import train_test_split

# %%
masks = glob.glob("Dataset_BUSI_with_GT/*/*_mask.png")
images = [mask_path.replace("_mask", "") for mask_path in masks]
series = []
for img_path, mask_path in zip(images, masks):
    if os.path.exists(img_path) and os.path.exists(mask_path):
        series.append((img_path, mask_path))
print(series[:4])
# Out:
# [('Dataset_BUSI_with_GT\\benign\\benign (1).png', 'Dataset_BUSI_with_GT\\benign\\benign (1)_mask.png'), ('Dataset_BUSI_with_GT\\benign\\benign (10).png', 'Dataset_BUSI_with_GT\\benign\\benign (10)_mask.png'), ('Dataset_BUSI_with_GT\\benign\\benign (100).png', 'Dataset_BUSI_with_GT\\benign\\benign (100)_mask.png'), ('Dataset_BUSI_with_GT\\benign\\benign (101).png', 'Dataset_BUSI_with_GT\\benign\\benign (101)_mask.png')]

# %%
def plot_train_label(image_mask):
    image = cv2.imread(image_mask[0])
    mask = cv2.imread(image_mask[1])
    
    f, axarr = plt.subplots(1, 3, figsize=(5, 5))
    
    axarr[0].imshow(np.squeeze(image), cmap='gray', origin='lower')
    axarr[0].set_ylabel('Axial View', fontsize=14)
    axarr[0].set_xticks([])
    axarr[0].set_yticks([])
    axarr[0].set_title('CT', fontsize=14)

    axarr[1].imshow(np.squeeze(mask), cmap='jet', origin='lower')
    axarr[1].axis('off')
    axarr[1].set_title('Mask', fontsize=14)

    axarr[2].imshow(np.squeeze(image), cmap='gray', alpha=1, origin='lower')
    axarr[2].imshow(np.squeeze(mask), cmap='jet', alpha=0.5, origin='lower')
    axarr[2].axis('off')
    axarr[2].set_title('Overlay', fontsize=14)

    plt.tight_layout()
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.show()

# %%
random_image = random.sample(range(750), 7)
for image in random_image:
    plot_train_label(series[image])

# %%
dataset = pd.DataFrame(series, columns=['image_path', 'mask_path'])

# %%
dataset
# Out:
#                                        image_path  \
# 0      Dataset_BUSI_with_GT\benign\benign (1).png
# 1     Dataset_BUSI_with_GT\benign\benign (10).png
# 2    Dataset_BUSI_with_GT\benign\benign (100).png
# 3    Dataset_BUSI_with_GT\benign\benign (101).png
# 4    Dataset_BUSI_with_GT\benign\benign (102).png
# ..                                            ...
# 775   Dataset_BUSI_with_GT\normal\normal (95).png
# 776   Dataset_BUSI_with_GT\normal\normal (96).png
# 777   Dataset_BUSI_with_GT\normal\normal (97).png
# 778   Dataset_BUSI_with_GT\normal\normal (98).png
# 779   Dataset_BUSI_with_GT\normal\normal (99).png
#
#                                              mask_path
# 0      Dataset_BUSI_with_GT\benign\benign (1)_mask.png
# 1     Dataset_BUSI_with_GT\benign\benign (10)_mask.png
# 2    Dataset_BUSI_with_GT\benign\benign (100)_mask.png
# 3    Dataset_BUSI_with_GT\benign\benign (101)_mask.png
# 4    Dataset_BUSI_with_GT\benign\benign (102)_mask.png
# ..                                                 ...
# 775   Dataset_BUSI_with_GT\normal\normal (95)_mask.png
# 776   Dataset_BUSI_with_GT\normal\normal (96)_mask.png
# 777   Dataset_BUSI_with_GT\normal\normal (97)_mask.png
# 778   Dataset_BUSI_with_GT\normal\normal (98)_mask.png
# 779   Dataset_BUSI_with_GT\normal\normal (99)_mask.png
#
# [780 rows x 2 columns]

# %%
train, test= train_test_split(dataset, test_size=0.25)

# %%
print(f"Train shape: {train.shape}")
print(f"Test shape: {test.shape}")
# Out:
# Train shape: (585, 2)
# Test shape: (195, 2)

# %%
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image

class CustomImageMaskDataset(Dataset):
    np.random.seed(42)
    torch.manual_seed(42)
    def __init__(self, dataframe, image_transform=None):
        self.data = dataframe
        self.image_transform = image_transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path = self.data.iloc[idx]['image_path']
        mask_path = self.data.iloc[idx]['mask_path']

        image = Image.open(image_path).convert('L') 
        mask = Image.open(mask_path).convert('L')

        if self.image_transform:
            image = self.image_transform(image)
            mask = self.image_transform(mask)

        return image, mask

# Define transformations with selected augmentation techniques and normalization for grayscale
image_size = 128
    
train_transforms = transforms.Compose([
    transforms.Resize([image_size, image_size]),
    transforms.ToTensor(),
])

val_transforms = transforms.Compose([
    transforms.Resize([image_size, image_size]),
    transforms.ToTensor(),
])


# Create datasets
train_dataset = CustomImageMaskDataset(train, train_transforms)
test_dataset = CustomImageMaskDataset(test, val_transforms)

# Create DataLoaders
batch_size = 16
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for batch in train_dataloader:
    # Assuming your dataset returns a tuple (inputs, targets)
    inputs, targets = batch
    
    # Print the shapes
    print("Input shape:", inputs.shape)
    print("Target shape:", targets.shape)
    break
# Out:
# Input shape: torch.Size([16, 1, 128, 128])
# Target shape: torch.Size([16, 1, 128, 128])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
class ConvBlock(nn.Module):
    def __init__(self, input_channel, out_channel, dropout):
        super(ConvBlock, self).__init__()
        self.conv2d_1 = nn.Conv2d(input_channel, out_channel, kernel_size=3, padding=1)
        self.batchnorm_1 = nn.BatchNorm2d(out_channel)
        self.relu_1 = nn.ReLU()
        
        self.dropout = nn.Dropout(dropout)
        
        self.conv2d_2 = nn.Conv2d(out_channel, out_channel, kernel_size=3, padding=1)
        self.batchnorm_2 = nn.BatchNorm2d(out_channel)
        self.relu_2 = nn.ReLU()

    def forward(self, x):
        x = self.conv2d_1(x)
        x = self.batchnorm_1(x)
        x = self.relu_1(x)
        
        x = self.dropout(x)
        
        x = self.conv2d_2(x)
        x = self.batchnorm_2(x)
        x = self.relu_2(x)

        return x

class Encoder(nn.Module):
    def __init__(self, input_channel, out_channel, dropout):
        super(Encoder, self).__init__()
        self.conv2d_1 = ConvBlock(input_channel, out_channel, dropout)
        self.maxpool = nn.MaxPool2d((2,2))
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        x = self.conv2d_1(x)
        p = self.maxpool(x)
        p = self.dropout(p)

        return x, p

class Decoder(nn.Module):
    def __init__(self, input_channel, output_channel, dropout):
        super(Decoder, self).__init__()
        self.conv_t = nn.ConvTranspose2d(input_channel, output_channel, stride=2, kernel_size=2)
        self.conv2d_1 = ConvBlock(output_channel*2, output_channel, dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, skip):
        x = self.conv_t(x)
        x = torch.cat([x, skip], dim=1)
        x = self.dropout(x)
        x = self.conv2d_1(x)

        return x

# %%
class Unet(nn.Module):

    def __init__(self, input_channel=1):
        super().__init__()
        self.encoder_1 = Encoder(input_channel, 64, 0.07)
        self.encoder_2 = Encoder(64, 128, 0.08)
        self.encoder_3 = Encoder(128, 256, 0.09)
        self.encoder_4 = Encoder(256, 512, 0.1)

        self.conv_block = ConvBlock(512, 1024, 0.11)

        self.decoder_1 = Decoder(1024, 512, 0.1)
        self.decoder_2 = Decoder(512, 256, 0.09)
        self.decoder_3 = Decoder(256, 128, 0.08)
        self.decoder_4 = Decoder(128, 64, 0.07)

        self.cls = nn.Conv2d(64, 1, kernel_size=1, padding=0)
        self.relu = nn.Sigmoid() 

    def forward(self, x):

        """ ------ Encoder ------"""
        x1, p1 = self.encoder_1(x)
        x2, p2 = self.encoder_2(p1)
        x3, p3 = self.encoder_3(p2)
        x4, p4 = self.encoder_4(p3)

        """ ------ BottleNeck ------"""
        x5 = self.conv_block(p4)

        """ ------ Decoder ------"""
        x6 = self.decoder_1(x5, x4)
        x7 = self.decoder_2(x6, x3)
        x8 = self.decoder_3(x7, x2)
        x9 = self.decoder_4(x8, x1)
        
        """ ------ Final Layer ------"""
        x_final = self.cls(x9)
        x_final = self.relu(x_final)

        return x_final

# %%
class Trainer:
    def __init__(self, model, num_epochs, optimizer, criterion, device):
        self.num_epochs = num_epochs
        self.optimizer = optimizer
        self.criterion = criterion
        self.model = model
        self.device = device
        self.log_interval = 15

        # Lists to store training and validation metrics
        self.train_losses = []
        self.val_losses = []
        self.train_dices = []
        self.val_dices = []

        # Best model and its metrics
        self.best_model = None
        self.best_dice = 0.0
        self.best_epoch = 0

    def dice_coeff(self, predicted, target, smooth=1e-5):
        intersection = torch.sum(predicted * target)
        union = torch.sum(predicted) + torch.sum(target)
        dice = (2. * intersection + smooth) / (union + smooth)
        return dice
    
    def iou(self, pred_mask, true_mask):
        intersection = torch.logical_and(pred_mask, true_mask).sum().item()
        union = torch.logical_or(pred_mask, true_mask).sum().item()
        iou_score = intersection / union if union != 0 else 0.0
        return iou_score

    def save_best_model(self, epoch, dice):
        if dice > self.best_dice:
            self.best_dice = dice
            self.best_epoch = epoch
            self.best_model = self.model.state_dict()

            filename = f'best_model_epoch{epoch}_dice{dice:.4f}.pth'
            torch.save(self.best_model, filename)

    def train(self, train_loader, val_loader):
        for epoch in range(self.num_epochs):
            train_loss = 0.0
            val_loss = 0.0
            train_dice = 0.0
            val_dice = 0.0

            # Training loop
            for i, (images, masks) in enumerate(train_loader):
                images, masks = images.to(self.device), masks.to(self.device)

                self.model.train()
                self.optimizer.zero_grad()

                outputs = self.model(images)
                loss = self.criterion(outputs, masks)
                dice = self.dice_coeff(outputs, masks)

                loss.backward()
                self.optimizer.step()

                train_loss += loss.item()
                train_dice += dice

                if (i + 1) % self.log_interval == 0:
                    print(f'Epoch [{epoch + 1}/{self.num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}, Dice Coef: {dice:.4f}')

            # Validation loop
            self.model.eval()
            with torch.no_grad():
                for images, masks in val_loader:
                    images, masks = images.to(self.device), masks.to(self.device)
                    outputs = self.model(images)
                    val_loss += self.criterion(outputs, masks).item()
                    val_dice += self.dice_coeff(outputs, masks)

            avg_train_loss = train_loss / len(train_loader)
            avg_val_loss = val_loss / len(val_loader)
            avg_train_dice = train_dice / len(train_loader)
            avg_val_dice = val_dice / len(val_loader)

            print(f'Epoch [{epoch + 1}/{self.num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
            print(f'Epoch [{epoch + 1}/{self.num_epochs}], Train Dice: {avg_train_dice:.4f}, Val Dice: {avg_val_dice:.4f}')

            # Save metrics
            self.train_losses.append(avg_train_loss)
            self.val_losses.append(avg_val_loss)
            self.train_dices.append(avg_train_dice)
            self.val_dices.append(avg_val_dice)

            # Save best model
            self.save_best_model(epoch + 1, avg_val_dice)
    def get_metrics(self):
        return {
            'train_losses': self.train_losses,
            'val_losses': self.val_losses,
            'train_dices': self.train_dices,
            'val_dices': self.val_dices,
            'best_model': self.best_model,
            'best_dice': self.best_dice,
            'best_epoch': self.best_epoch
        }

# %%
def dice_coef_loss(inputs, target):
    smooth = 1e-6
    intersection = 2.0 * (target*inputs).sum() + smooth
    union = target.sum() + inputs.sum() + smooth
    return 1 - (intersection/union)

def bce_dice_loss(inputs, target):
    dice_score = dice_coef_loss(inputs, target)
    bce_loss = nn.BCELoss()
    bce_score = bce_loss(inputs, target)
    
    return bce_score + dice_score

# %%
unet = Unet(1).to(device)

# %%
learning_rate = 0.0001
weight_decay = 1e-6  # Regularization term to prevent overfitting

optimizer = optim.Adam(unet.parameters(), lr=learning_rate, weight_decay=weight_decay)

trainer = Trainer(model=unet, num_epochs=100, optimizer=optimizer, criterion=bce_dice_loss, device=device)

# %%
trainer.train(train_dataloader, test_dataloader)
metrics = trainer.get_metrics()
# Out:
# Epoch [1/100], Step [15/37], Loss: 0.0310, Dice Coef: 0.9768
# Epoch [1/100], Step [30/37], Loss: 0.0395, Dice Coef: 0.9680
# Epoch [1/100], Train Loss: 0.0338, Val Loss: 0.6059
# Epoch [1/100], Train Dice: 0.9757, Val Dice: 0.7151
# Epoch [2/100], Step [15/37], Loss: 0.0419, Dice Coef: 0.9681
# Epoch [2/100], Step [30/37], Loss: 0.0409, Dice Coef: 0.9676
# Epoch [2/100], Train Loss: 0.0362, Val Loss: 0.6244
# Epoch [2/100], Train Dice: 0.9739, Val Dice: 0.7065
# Epoch [3/100], Step [15/37], Loss: 0.0373, Dice Coef: 0.9741
# Epoch [3/100], Step [30/37], Loss: 0.0303, Dice Coef: 0.9779
# Epoch [3/100], Train Loss: 0.0355, Val Loss: 0.6397
# Epoch [3/100], Train Dice: 0.9746, Val Dice: 0.6950
# Epoch [4/100], Step [15/37], Loss: 0.0315, Dice Coef: 0.9772
# Epoch [4/100], Step [30/37], Loss: 0.0362, Dice Coef: 0.9776
# Epoch [4/100], Train Loss: 0.0346, Val Loss: 0.6478
# Epoch [4/100], Train Dice: 0.9752, Val Dice: 0.6927
# Epoch [5/100], Step [15/37], Loss: 0.0352, Dice Coef: 0.9748
# Epoch [5/100], Step [30/37], Loss: 0.0328, Dice Coef: 0.9763
# Epoch [5/100], Train Loss: 0.0362, Val Loss: 0.6169
# Epoch [5/100], Train Dice: 0.9740, Val Dice: 0.7085
# Epoch [6/100], Step [15/37], Loss: 0.0329, Dice Coef: 0.9766
# Epoch [6/100], Step [30/37], Loss: 0.0289, Dice Coef: 0.9781
# Epoch [6/100], Train Loss: 0.0339, Val Loss: 0.6293
# Epoch [6/100], Train Dice: 0.9755, Val Dice: 0.7000
# Epoch [7/100], Step [15/37], Loss: 0.0325, Dice Coef: 0.9781
# Epoch [7/100], Step [30/37], Loss: 0.0256, Dice Coef: 0.9821
# Epoch [7/100], Train Loss: 0.0329, Val Loss: 0.6694
# Epoch [7/100], Train Dice: 0.9763, Val Dice: 0.6842
# Epoch [8/100], Step [15/37], Loss: 0.0337, Dice Coef: 0.9754
# Epoch [8/100], Step [30/37], Loss: 0.0358, Dice Coef: 0.9725
# Epoch [8/100], Train Loss: 0.0328, Val Loss: 0.6525
# Epoch [8/100], Train Dice: 0.9762, Val Dice: 0.6932
# Epoch [9/100], Step [15/37], Loss: 0.0322, Dice Coef: 0.9753
# Epoch [9/100], Step [30/37], Loss: 0.0322, Dice Coef: 0.9754
# Epoch [9/100], Train Loss: 0.0322, Val Loss: 0.6737
# Epoch [9/100], Train Dice: 0.9766, Val Dice: 0.6836
# Epoch [10/100], Step [15/37], Loss: 0.0274, Dice Coef: 0.9796
# Epoch [10/100], Step [30/37], Loss: 0.0299, Dice Coef: 0.9790
# Epoch [10/100], Train Loss: 0.0328, Val Loss: 0.6778
# Epoch [10/100], Train Dice: 0.9760, Val Dice: 0.6839
# Epoch [11/100], Step [15/37], Loss: 0.0427, Dice Coef: 0.9737
# Epoch [11/100], Step [30/37], Loss: 0.0352, Dice Coef: 0.9720
# Epoch [11/100], Train Loss: 0.0348, Val Loss: 0.6408
# Epoch [11/100], Train Dice: 0.9750, Val Dice: 0.6969
# Epoch [12/100], Step [15/37], Loss: 0.0291, Dice Coef: 0.9806
# Epoch [12/100], Step [30/37], Loss: 0.0353, Dice Coef: 0.9754
# Epoch [12/100], Train Loss: 0.0336, Val Loss: 0.6099
# Epoch [12/100], Train Dice: 0.9760, Val Dice: 0.7138
# Epoch [13/100], Step [15/37], Loss: 0.0300, Dice Coef: 0.9804
# Epoch [13/100], Step [30/37], Loss: 0.0346, Dice Coef: 0.9747
# Epoch [13/100], Train Loss: 0.0324, Val Loss: 0.6331
# Epoch [13/100], Train Dice: 0.9765, Val Dice: 0.7036
# Epoch [14/100], Step [15/37], Loss: 0.0275, Dice Coef: 0.9825
# Epoch [14/100], Step [30/37], Loss: 0.0297, Dice Coef: 0.9799
# Epoch [14/100], Train Loss: 0.0308, Val Loss: 0.6436
# Epoch [14/100], Train Dice: 0.9778, Val Dice: 0.7006
# Epoch [15/100], Step [15/37], Loss: 0.0279, Dice Coef: 0.9790
# Epoch [15/100], Step [30/37], Loss: 0.0301, Dice Coef: 0.9799
# Epoch [15/100], Train Loss: 0.0309, Val Loss: 0.6598
# Epoch [15/100], Train Dice: 0.9776, Val Dice: 0.6964
# Epoch [16/100], Step [15/37], Loss: 0.0293, Dice Coef: 0.9783
# Epoch [16/100], Step [30/37], Loss: 0.0250, Dice Coef: 0.9824
# Epoch [16/100], Train Loss: 0.0302, Val Loss: 0.6641
# Epoch [16/100], Train Dice: 0.9781, Val Dice: 0.6963
# Epoch [17/100], Step [15/37], Loss: 0.0410, Dice Coef: 0.9695
# Epoch [17/100], Step [30/37], Loss: 0.0322, Dice Coef: 0.9752
# Epoch [17/100], Train Loss: 0.0312, Val Loss: 0.6422
# Epoch [17/100], Train Dice: 0.9775, Val Dice: 0.7065
# Epoch [18/100], Step [15/37], Loss: 0.0308, Dice Coef: 0.9801
# Epoch [18/100], Step [30/37], Loss: 0.0310, Dice Coef: 0.9790
# Epoch [18/100], Train Loss: 0.0307, Val Loss: 0.6673
# Epoch [18/100], Train Dice: 0.9778, Val Dice: 0.6966
# Epoch [19/100], Step [15/37], Loss: 0.0291, Dice Coef: 0.9822
# Epoch [19/100], Step [30/37], Loss: 0.0403, Dice Coef: 0.9672
# Epoch [19/100], Train Loss: 0.0307, Val Loss: 0.6624
# Epoch [19/100], Train Dice: 0.9777, Val Dice: 0.6995
# Epoch [20/100], Step [15/37], Loss: 0.0259, Dice Coef: 0.9805
# Epoch [20/100], Step [30/37], Loss: 0.0314, Dice Coef: 0.9762
# Epoch [20/100], Train Loss: 0.0314, Val Loss: 0.6160
# Epoch [20/100], Train Dice: 0.9777, Val Dice: 0.7167
# Epoch [21/100], Step [15/37], Loss: 0.0292, Dice Coef: 0.9798
# Epoch [21/100], Step [30/37], Loss: 0.0298, Dice Coef: 0.9795
# Epoch [21/100], Train Loss: 0.0312, Val Loss: 0.6471
# Epoch [21/100], Train Dice: 0.9777, Val Dice: 0.7036
# Epoch [22/100], Step [15/37], Loss: 0.0269, Dice Coef: 0.9801
# Epoch [22/100], Step [30/37], Loss: 0.0318, Dice Coef: 0.9770
# Epoch [22/100], Train Loss: 0.0303, Val Loss: 0.6741
# Epoch [22/100], Train Dice: 0.9781, Val Dice: 0.6896
# Epoch [23/100], Step [15/37], Loss: 0.0315, Dice Coef: 0.9774
# Epoch [23/100], Step [30/37], Loss: 0.0233, Dice Coef: 0.9831
# Epoch [23/100], Train Loss: 0.0297, Val Loss: 0.6594
# Epoch [23/100], Train Dice: 0.9785, Val Dice: 0.7000
# Epoch [24/100], Step [15/37], Loss: 0.0271, Dice Coef: 0.9817
# Epoch [24/100], Step [30/37], Loss: 0.0283, Dice Coef: 0.9818
# Epoch [44/100], Train Dice: 0.8836, Val Dice: 0.7018
# Epoch [45/100], Step [15/37], Loss: 0.0671, Dice Coef: 0.9522
# Epoch [45/100], Step [30/37], Loss: 0.0591, Dice Coef: 0.9603
# Epoch [45/100], Train Loss: 0.0802, Val Loss: 0.5813
# Epoch [45/100], Train Dice: 0.9423, Val Dice: 0.6999
# Epoch [46/100], Step [15/37], Loss: 0.0546, Dice Coef: 0.9596
# Epoch [46/100], Step [30/37], Loss: 0.0364, Dice Coef: 0.9730
# Epoch [46/100], Train Loss: 0.0516, Val Loss: 0.5434
# Epoch [46/100], Train Dice: 0.9631, Val Dice: 0.7279
# Epoch [47/100], Step [15/37], Loss: 0.0530, Dice Coef: 0.9630
# Epoch [47/100], Step [30/37], Loss: 0.0385, Dice Coef: 0.9691
# Epoch [47/100], Train Loss: 0.0465, Val Loss: 0.5561
# Epoch [47/100], Train Dice: 0.9677, Val Dice: 0.7232
# Epoch [48/100], Step [15/37], Loss: 0.0339, Dice Coef: 0.9753
# Epoch [48/100], Step [30/37], Loss: 0.0624, Dice Coef: 0.9602
# Epoch [48/100], Train Loss: 0.0387, Val Loss: 0.5623
# Epoch [48/100], Train Dice: 0.9728, Val Dice: 0.7237
# Epoch [49/100], Step [15/37], Loss: 0.0360, Dice Coef: 0.9738
# Epoch [49/100], Step [30/37], Loss: 0.0337, Dice Coef: 0.9759
# Epoch [49/100], Train Loss: 0.0372, Val Loss: 0.5358
# Epoch [49/100], Train Dice: 0.9735, Val Dice: 0.7390
# Epoch [50/100], Step [15/37], Loss: 0.0343, Dice Coef: 0.9748
# Epoch [50/100], Step [30/37], Loss: 0.0346, Dice Coef: 0.9751
# Epoch [50/100], Train Loss: 0.0360, Val Loss: 0.5532
# Epoch [50/100], Train Dice: 0.9745, Val Dice: 0.7288
# Epoch [51/100], Step [15/37], Loss: 0.0318, Dice Coef: 0.9785
# Epoch [51/100], Step [30/37], Loss: 0.0468, Dice Coef: 0.9682
# Epoch [51/100], Train Loss: 0.0342, Val Loss: 0.5722
# Epoch [51/100], Train Dice: 0.9756, Val Dice: 0.7222
# Epoch [52/100], Step [15/37], Loss: 0.0324, Dice Coef: 0.9763
# Epoch [52/100], Step [30/37], Loss: 0.0241, Dice Coef: 0.9846
# Epoch [52/100], Train Loss: 0.0343, Val Loss: 0.5514
# Epoch [52/100], Train Dice: 0.9755, Val Dice: 0.7339
# Epoch [53/100], Step [15/37], Loss: 0.0302, Dice Coef: 0.9771
# Epoch [53/100], Step [30/37], Loss: 0.0270, Dice Coef: 0.9807
# Epoch [53/100], Train Loss: 0.0320, Val Loss: 0.5735
# Epoch [53/100], Train Dice: 0.9768, Val Dice: 0.7250
# Epoch [54/100], Step [15/37], Loss: 0.0261, Dice Coef: 0.9812
# Epoch [54/100], Step [30/37], Loss: 0.0264, Dice Coef: 0.9804
# Epoch [54/100], Train Loss: 0.0318, Val Loss: 0.5901
# Epoch [64/100], Train Dice: 0.9789, Val Dice: 0.7039
# Epoch [65/100], Step [15/37], Loss: 0.0270, Dice Coef: 0.9815
# Epoch [65/100], Step [30/37], Loss: 0.0256, Dice Coef: 0.9830
# Epoch [65/100], Train Loss: 0.0295, Val Loss: 0.6342
# Epoch [65/100], Train Dice: 0.9785, Val Dice: 0.7050
# Epoch [66/100], Step [15/37], Loss: 0.0283, Dice Coef: 0.9795
# Epoch [66/100], Step [30/37], Loss: 0.0315, Dice Coef: 0.9762
# Epoch [66/100], Train Loss: 0.0291, Val Loss: 0.6296
# Epoch [66/100], Train Dice: 0.9788, Val Dice: 0.7116
# Epoch [67/100], Step [15/37], Loss: 0.0279, Dice Coef: 0.9803
# Epoch [67/100], Step [30/37], Loss: 0.0315, Dice Coef: 0.9762
# Epoch [67/100], Train Loss: 0.0291, Val Loss: 0.6270
# Epoch [67/100], Train Dice: 0.9789, Val Dice: 0.7133
# Epoch [68/100], Step [15/37], Loss: 0.0301, Dice Coef: 0.9763
# Epoch [68/100], Step [30/37], Loss: 0.0334, Dice Coef: 0.9766
# Epoch [68/100], Train Loss: 0.0289, Val Loss: 0.6025
# Epoch [68/100], Train Dice: 0.9789, Val Dice: 0.7263
# Epoch [69/100], Step [15/37], Loss: 0.0297, Dice Coef: 0.9788
# Epoch [69/100], Step [30/37], Loss: 0.0347, Dice Coef: 0.9700
# Epoch [69/100], Train Loss: 0.0294, Val Loss: 0.6101
# Epoch [69/100], Train Dice: 0.9785, Val Dice: 0.7266
# Epoch [70/100], Step [15/37], Loss: 0.0310, Dice Coef: 0.9769
# Epoch [70/100], Step [30/37], Loss: 0.0256, Dice Coef: 0.9832
# Epoch [70/100], Train Loss: 0.0291, Val Loss: 0.6274
# Epoch [70/100], Train Dice: 0.9788, Val Dice: 0.7149
# Epoch [71/100], Step [15/37], Loss: 0.0285, Dice Coef: 0.9793
# Epoch [71/100], Step [30/37], Loss: 0.0251, Dice Coef: 0.9836
# Epoch [71/100], Train Loss: 0.0286, Val Loss: 0.6275
# Epoch [71/100], Train Dice: 0.9792, Val Dice: 0.7155
# Epoch [72/100], Step [15/37], Loss: 0.0321, Dice Coef: 0.9761
# Epoch [72/100], Step [30/37], Loss: 0.0329, Dice Coef: 0.9751
# Epoch [72/100], Train Loss: 0.0284, Val Loss: 0.6465
# Epoch [72/100], Train Dice: 0.9794, Val Dice: 0.7058
# Epoch [73/100], Step [15/37], Loss: 0.0299, Dice Coef: 0.9801
# Epoch [73/100], Step [30/37], Loss: 0.0293, Dice Coef: 0.9789
# Epoch [73/100], Train Loss: 0.0283, Val Loss: 0.6490
# Epoch [73/100], Train Dice: 0.9795, Val Dice: 0.7048
# Epoch [74/100], Step [15/37], Loss: 0.0286, Dice Coef: 0.9806
# Epoch [74/100], Step [30/37], Loss: 0.0320, Dice Coef: 0.9751
# Epoch [74/100], Train Loss: 0.0289, Val Loss: 0.6493
# Epoch [74/100], Train Dice: 0.9790, Val Dice: 0.7034
# Epoch [75/100], Step [15/37], Loss: 0.0337, Dice Coef: 0.9733
# Epoch [75/100], Step [30/37], Loss: 0.0276, Dice Coef: 0.9803
# Epoch [75/100], Train Loss: 0.0282, Val Loss: 0.6469
# Epoch [75/100], Train Dice: 0.9795, Val Dice: 0.7065
# Epoch [76/100], Step [15/37], Loss: 0.0260, Dice Coef: 0.9836
# Epoch [76/100], Step [30/37], Loss: 0.0296, Dice Coef: 0.9770
# Epoch [76/100], Train Loss: 0.0280, Val Loss: 0.6434
# Epoch [76/100], Train Dice: 0.9797, Val Dice: 0.7089
# Epoch [77/100], Step [15/37], Loss: 0.0267, Dice Coef: 0.9836
# Epoch [77/100], Step [30/37], Loss: 0.0243, Dice Coef: 0.9833
# Epoch [77/100], Train Loss: 0.0281, Val Loss: 0.6403
# Epoch [77/100], Train Dice: 0.9795, Val Dice: 0.7115
# Epoch [78/100], Step [15/37], Loss: 0.0267, Dice Coef: 0.9815
# Epoch [78/100], Step [30/37], Loss: 0.0298, Dice Coef: 0.9772
# Epoch [78/100], Train Loss: 0.0285, Val Loss: 0.6401
# Epoch [78/100], Train Dice: 0.9793, Val Dice: 0.7117
# Epoch [79/100], Step [15/37], Loss: 0.0319, Dice Coef: 0.9760
# Epoch [79/100], Step [30/37], Loss: 0.0272, Dice Coef: 0.9811
# Epoch [79/100], Train Loss: 0.0283, Val Loss: 0.6353
# Epoch [79/100], Train Dice: 0.9794, Val Dice: 0.7144
# Epoch [80/100], Step [15/37], Loss: 0.0280, Dice Coef: 0.9808
# Epoch [80/100], Step [30/37], Loss: 0.0287, Dice Coef: 0.9792
# Epoch [80/100], Train Loss: 0.0283, Val Loss: 0.6312
# Epoch [80/100], Train Dice: 0.9794, Val Dice: 0.7167
# Epoch [81/100], Step [15/37], Loss: 0.0271, Dice Coef: 0.9814
# Epoch [81/100], Step [30/37], Loss: 0.0228, Dice Coef: 0.9855
# Epoch [81/100], Train Loss: 0.0279, Val Loss: 0.6555
# Epoch [81/100], Train Dice: 0.9798, Val Dice: 0.7044
# Epoch [82/100], Step [15/37], Loss: 0.0277, Dice Coef: 0.9783
# Epoch [82/100], Step [30/37], Loss: 0.0277, Dice Coef: 0.9794
# Epoch [82/100], Train Loss: 0.0281, Val Loss: 0.6638
# Epoch [82/100], Train Dice: 0.9796, Val Dice: 0.7006
# Epoch [83/100], Step [15/37], Loss: 0.0287, Dice Coef: 0.9788
# Epoch [83/100], Step [30/37], Loss: 0.0267, Dice Coef: 0.9815
# Epoch [83/100], Train Loss: 0.0278, Val Loss: 0.6526
# Epoch [83/100], Train Dice: 0.9798, Val Dice: 0.7063
# Epoch [84/100], Step [15/37], Loss: 0.0258, Dice Coef: 0.9807
# Epoch [84/100], Step [30/37], Loss: 0.0244, Dice Coef: 0.9849
# Epoch [84/100], Train Loss: 0.0282, Val Loss: 0.6436
# Epoch [84/100], Train Dice: 0.9795, Val Dice: 0.7118
# Epoch [85/100], Step [15/37], Loss: 0.0298, Dice Coef: 0.9759
# Epoch [85/100], Step [30/37], Loss: 0.0235, Dice Coef: 0.9839
# Epoch [85/100], Train Loss: 0.0279, Val Loss: 0.6572
# Epoch [85/100], Train Dice: 0.9797, Val Dice: 0.7051
# Epoch [86/100], Step [15/37], Loss: 0.0293, Dice Coef: 0.9788
# Epoch [86/100], Step [30/37], Loss: 0.0293, Dice Coef: 0.9779
# Epoch [86/100], Train Loss: 0.0276, Val Loss: 0.6567
# Epoch [86/100], Train Dice: 0.9800, Val Dice: 0.7058
# Epoch [87/100], Step [15/37], Loss: 0.0268, Dice Coef: 0.9824
# Epoch [87/100], Step [30/37], Loss: 0.0266, Dice Coef: 0.9805
# Epoch [87/100], Train Loss: 0.0278, Val Loss: 0.6458
# Epoch [87/100], Train Dice: 0.9798, Val Dice: 0.7118
# Epoch [88/100], Step [15/37], Loss: 0.0284, Dice Coef: 0.9811
# Epoch [88/100], Step [30/37], Loss: 0.0290, Dice Coef: 0.9794
# Epoch [88/100], Train Loss: 0.0283, Val Loss: 0.6511
# Epoch [88/100], Train Dice: 0.9794, Val Dice: 0.7093
# Epoch [89/100], Step [15/37], Loss: 0.0249, Dice Coef: 0.9824
# Epoch [89/100], Step [30/37], Loss: 0.0263, Dice Coef: 0.9815
# Epoch [89/100], Train Loss: 0.0279, Val Loss: 0.6500
# Epoch [89/100], Train Dice: 0.9797, Val Dice: 0.7091
# Epoch [90/100], Step [15/37], Loss: 0.0285, Dice Coef: 0.9777
# Epoch [90/100], Step [30/37], Loss: 0.0289, Dice Coef: 0.9807
# Epoch [90/100], Train Loss: 0.0279, Val Loss: 0.6485
# Epoch [90/100], Train Dice: 0.9798, Val Dice: 0.7093
# Epoch [91/100], Step [15/37], Loss: 0.0280, Dice Coef: 0.9815
# Epoch [91/100], Step [30/37], Loss: 0.0314, Dice Coef: 0.9737
# Epoch [91/100], Train Loss: 0.0278, Val Loss: 0.6552
# Epoch [91/100], Train Dice: 0.9798, Val Dice: 0.7066
# Epoch [92/100], Step [15/37], Loss: 0.0277, Dice Coef: 0.9811
# Epoch [92/100], Step [30/37], Loss: 0.0283, Dice Coef: 0.9797
# Epoch [92/100], Train Loss: 0.0283, Val Loss: 0.6172
# Epoch [92/100], Train Dice: 0.9795, Val Dice: 0.7271
# Epoch [93/100], Step [15/37], Loss: 0.0287, Dice Coef: 0.9821
# Epoch [93/100], Step [30/37], Loss: 0.0292, Dice Coef: 0.9799
# Epoch [93/100], Train Loss: 0.0283, Val Loss: 0.6272
# Epoch [93/100], Train Dice: 0.9795, Val Dice: 0.7209
# Epoch [94/100], Step [15/37], Loss: 0.0285, Dice Coef: 0.9800
# Epoch [94/100], Step [30/37], Loss: 0.0293, Dice Coef: 0.9790
# Epoch [94/100], Train Loss: 0.0278, Val Loss: 0.6346
# Epoch [94/100], Train Dice: 0.9799, Val Dice: 0.7172
# Epoch [95/100], Step [15/37], Loss: 0.0269, Dice Coef: 0.9785
# Epoch [95/100], Step [30/37], Loss: 0.0264, Dice Coef: 0.9801
# Epoch [95/100], Train Loss: 0.0279, Val Loss: 0.6396
# Epoch [95/100], Train Dice: 0.9798, Val Dice: 0.7144
# Epoch [96/100], Step [15/37], Loss: 0.0311, Dice Coef: 0.9762
# Epoch [96/100], Step [30/37], Loss: 0.0313, Dice Coef: 0.9768
# Epoch [96/100], Train Loss: 0.0282, Val Loss: 0.6297
# Epoch [96/100], Train Dice: 0.9794, Val Dice: 0.7229
# Epoch [97/100], Step [15/37], Loss: 0.0256, Dice Coef: 0.9819
# Epoch [97/100], Step [30/37], Loss: 0.0253, Dice Coef: 0.9818
# Epoch [97/100], Train Loss: 0.0282, Val Loss: 0.6364
# Epoch [97/100], Train Dice: 0.9796, Val Dice: 0.7139
# Epoch [98/100], Step [15/37], Loss: 0.0249, Dice Coef: 0.9824
# Epoch [98/100], Step [30/37], Loss: 0.0233, Dice Coef: 0.9851
# Epoch [98/100], Train Loss: 0.0281, Val Loss: 0.6414
# Epoch [98/100], Train Dice: 0.9796, Val Dice: 0.7127
# Epoch [99/100], Step [15/37], Loss: 0.0280, Dice Coef: 0.9796
# Epoch [99/100], Step [30/37], Loss: 0.0294, Dice Coef: 0.9798
# Epoch [99/100], Train Loss: 0.0292, Val Loss: 0.6302
# Epoch [99/100], Train Dice: 0.9789, Val Dice: 0.7232
# Epoch [100/100], Step [15/37], Loss: 0.0297, Dice Coef: 0.9786
# Epoch [100/100], Step [30/37], Loss: 0.0246, Dice Coef: 0.9833
# Epoch [100/100], Train Loss: 0.0283, Val Loss: 0.6430
# Epoch [100/100], Train Dice: 0.9794, Val Dice: 0.7164

# %%
import matplotlib.pyplot as plt
import numpy as np

def to_numpy(tensor):
    # Move tensor to CPU and convert to NumPy array
    return tensor.cpu().detach().numpy()

def threshold_prediction(predicted, threshold=0.5):
    # Threshold predicted values
    predicted[predicted < threshold] = 0
    predicted[predicted >= threshold] = 1
    return predicted

def plot_subplots(image, mask, predicted, threshold=0.5):
    # Convert tensors to NumPy arrays
    image_np, mask_np, predicted_np = map(to_numpy, (image, mask, predicted))

    # Threshold the predicted values
    predicted_np_thresholded = threshold_prediction(predicted_np, threshold)

    fig, axes = plt.subplots(1, 3, figsize=(10, 5))  # Adjust figsize as needed

    # Plot Image, Mask, Predicted, and Thresholded Predicted
    titles = ['Image', 'Mask', 'Predicted']
    for ax, data, title in zip(axes, [image_np, mask_np, predicted_np, predicted_np_thresholded], titles):
        ax.imshow(data.squeeze(), cmap='gray' if 'Mask' in title else 'gray')
        ax.set_title(title)
        ax.axis('off')

    plt.show()

# %%
for i in [2, 3, 11, 20, 55, 67, 87, 98, 120, 130, 200]:
    image = train_dataset[i][0]
    mask = train_dataset[i][1]
    im = image.to(device)
    pred = unet(im.unsqueeze(0))
    pred = pred.squeeze()

    plot_subplots(im, mask, pred)
